# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import os

# %%
df = pd.read_csv('./dataset/preprocessed_iris.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0           0.222222          0.625000           0.067797          0.041667
# 1           0.166667          0.416667           0.067797          0.041667
# 2           0.111111          0.500000           0.050847          0.041667
# 3           0.083333          0.458333           0.084746          0.041667
# 4           0.194444          0.666667           0.067797          0.041667
#
#    target  sepal_to_petal_ratio
# 0     0.0              3.277778
# 1     0.0              2.458333
# 2     0.0              2.185185
# 3     0.0              0.983333
# 4     0.0              2.868056

# %%
X = df.drop('target', axis=1)
y = df.target

# %%
mean_values = X.mean()
median_values = df.median()
variance_values = df.var()
std_dev_values = df.std()


print("Mean values:\n",mean_values)
print("\nMedian values:\n", median_values)
print("\nVariance values:\n", variance_values)
print("\nStandard deviation values:\n", std_dev_values)
# Out:
# Mean values:
#  sepal length (cm)       0.428704
# sepal width (cm)        0.440556
# petal length (cm)       0.467458
# petal width (cm)        0.458056
# sepal_to_petal_ratio         inf
# dtype: float64
#
# Median values:
#  sepal length (cm)       0.416667
# sepal width (cm)        0.416667
# petal length (cm)       0.567797
# petal width (cm)        0.500000
# target                  1.000000
# sepal_to_petal_ratio    0.922725
# dtype: float64
#
# Variance values:
#  sepal length (cm)       0.052908
# sepal width (cm)        0.032983
# petal length (cm)       0.089522
# petal width (cm)        0.100869
# target                  0.671141
# sepal_to_petal_ratio         NaN
# dtype: float64
#
# Standard deviation values:
#  sepal length (cm)       0.230018
# sepal width (cm)        0.181611
# petal length (cm)       0.299203
# petal width (cm)        0.317599
# target                  0.819232
# sepal_to_petal_ratio         NaN
# dtype: float64
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)

# %%
corr = X.corr()

# %%
sns.heatmap(corr, annot=True, )
plt.show()
