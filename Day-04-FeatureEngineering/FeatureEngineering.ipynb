# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msno
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,LabelEncoder  

import os

# %%
df = pd.read_csv('./dataset/preprocessed_titanic.csv')
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0       0.0     3.0    male  22.0    1.0    0.0   7.2500        S  Third
# 1       1.0     1.0  female  38.0    1.0    0.0  71.2833        C  First
# 2       1.0     3.0  female  26.0    0.0    0.0   7.9250        S  Third
# 3       1.0     1.0  female  35.0    1.0    0.0  53.1000        S  First
# 4       0.0     3.0    male  35.0    0.0    0.0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True

# %%
# making family size feature
df['family_size'] = df['sibsp'] + df['parch'] +1
# is alone feature
df['is_alone'] = (df['family_size'] == 1).astype(int)

# binning age and fare
df['age_group'] =pd.cut(df['age'], bins=[0, 12, 18, 60, 100], labels=['Child', 'Teen', 'Adult', 'Senior'])
df['fare_group'] = pd.qcut(df['fare'], q=3, labels=['Low Fare', 'Medium Fare', 'High Fare'])
df.head(10)
# Out:
#    survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0       0.0     3.0    male  22.000000    1.0    0.0   7.2500        S
# 1       1.0     1.0  female  38.000000    1.0    0.0  71.2833        C
# 2       1.0     3.0  female  26.000000    0.0    0.0   7.9250        S
# 3       1.0     1.0  female  35.000000    1.0    0.0  53.1000        S
# 4       0.0     3.0    male  35.000000    0.0    0.0   8.0500        S
# 5       0.0     3.0    male  29.699118    0.0    0.0   8.4583        Q
# 6       0.0     1.0    male  54.000000    0.0    0.0  51.8625        S
# 7       0.0     3.0    male   2.500000    3.0    1.0  21.0750        S
# 8       1.0     3.0  female  27.000000    0.0    2.0  11.1333        S
# 9       1.0     2.0  female  14.000000    1.0    0.0  30.0708        C
#
#     class    who  adult_male deck  embark_town alive  alone  family_size  \
# 0   Third    man        True    C  Southampton    no  False          1.0
# 1   First  woman       False    C    Cherbourg   yes  False          1.0
# 2   Third  woman       False    C  Southampton   yes   True          0.0
# 3   First  woman       False    C  Southampton   yes  False          1.0
# 4   Third    man        True    C  Southampton    no   True          0.0
# 5   Third    man        True    C   Queenstown    no   True          0.0
# 6   First    man        True    E  Southampton    no   True          0.0
# 7   Third  child       False    C  Southampton    no  False          4.0
# 8   Third  woman       False    C  Southampton   yes  False          2.0
# 9  Second  child       False    C    Cherbourg   yes  False          1.0
#
#    is_alone age_group   fare_group
# 0         0     Adult     Low Fare
# 1         0     Adult    High Fare
# 2         1     Adult     Low Fare
# 3         0     Adult    High Fare
# 4         1     Adult     Low Fare
# 5         1     Adult     Low Fare
# 6         1     Adult    High Fare
# 7         0     Child  Medium Fare
# 8         0     Adult  Medium Fare
# 9         0      Teen    High Fare

# %%
# Encoding
# One-hot encoding for nominal features
df = pd.get_dummies(df, columns=['sex', 'embarked', 'who', 'embark_town'], drop_first=True)

# Label encoding for ordinal features
le = LabelEncoder()
df['age_group'] = le.fit_transform(df['age_group'])
df['fare_group'] = le.fit_transform(df['fare_group'])

# Display the transformed DataFrame
df.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  class  adult_male deck  \
# 0       0.0     3.0  22.0    1.0    0.0   7.2500  Third        True    C
# 1       1.0     1.0  38.0    1.0    0.0  71.2833  First       False    C
# 2       1.0     3.0  26.0    0.0    0.0   7.9250  Third       False    C
# 3       1.0     1.0  35.0    1.0    0.0  53.1000  First       False    C
# 4       0.0     3.0  35.0    0.0    0.0   8.0500  Third        True    C
#
#   alive  ...  is_alone  age_group  fare_group  sex_male  embarked_Q  \
# 0    no  ...         0          0           1      True       False
# 1   yes  ...         0          0           0     False       False
# 2   yes  ...         1          0           1     False       False
# 3   yes  ...         0          0           0     False       False
# 4    no  ...         1          0           1      True       False
#
#    embarked_S  who_man  who_woman  embark_town_Queenstown  \
# 0        True     True      False                   False
# 1       False    False       True                   False
# 2        True    False       True                   False
# 3        True    False       True                   False
# 4        True     True      False                   False
#
#    embark_town_Southampton
# 0                     True
# 1                    False
# 2                     True
# 3                     True
# 4                     True
#
# [5 rows x 22 columns]
